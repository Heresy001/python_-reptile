# %%
import requests
import json
import time
import random

#下载第一页数据
def get_one_page(url):
 headers = {
   'User-Agent':'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/64.0.3282.140 Safari/537.36'
 }
 response = requests.get(url,headers=headers)
 if response.status_code == 200:
   return response.text
 return None

#解析第一页数据
def parse_one_page(html):
 data = json.loads(html)['cmts']
 for item in data:
   yield{
   'comment':item['content'],
   'date':item['time'].split(' ')[0],
   'rate':item['score'],
   'city':item['cityName'],
   'nickname':item['nickName']
   }

#保存数据到文本文档
def save_to_txt():
 for i in range(1,1001):
   url = 'https://m.maoyan.com/mmdb/comments/movie/248566.json?_v_=yes&offset=' + str(i)
   html = get_one_page(url)
   print('正在保存第%d页。'% i)
   for item in parse_one_page(html):
     with open('xie_zheng.txt','a',encoding='utf-8') as f:
       f.write(item['date'] + ',' + item['nickname'] + ',' + item['city'] + ',' +str(item['rate'])+','+item['comment']+'\n')
   time.sleep(5 + float(random.randint(1, 100)) / 20)

if __name__ == '__main__':
 save_to_txt()
# Out:
# 正在保存第1页。
# 正在保存第2页。
# 正在保存第3页。
# 正在保存第4页。
# 正在保存第5页。
# 正在保存第6页。
# 正在保存第7页。
# 正在保存第8页。
# 正在保存第9页。
# 正在保存第10页。
# 正在保存第11页。
# 正在保存第12页。
# 正在保存第13页。
# 正在保存第14页。
# 正在保存第15页。
# 正在保存第16页。
# 正在保存第17页。
# 正在保存第18页。
# 正在保存第19页。
# 正在保存第20页。
# 正在保存第21页。
# 正在保存第22页。
# 正在保存第23页。
# 正在保存第24页。
# 正在保存第25页。
# 正在保存第26页。
# 正在保存第27页。
# 正在保存第28页。
# 正在保存第29页。
# 正在保存第30页。
# 正在保存第31页。
# 正在保存第32页。
# 正在保存第33页。
# 正在保存第34页。
# 正在保存第35页。
# 正在保存第36页。
# 正在保存第37页。
# 正在保存第38页。
# 正在保存第39页。
# 正在保存第40页。
# 正在保存第41页。
# 正在保存第42页。

# %%
import pandas as pd
import numpy as np
dd = open(r'C:\Users\Administrator\爬虫_练习\xie_zheng.txt',encoding='utf-8')
TT = dd.readlines()
TT

# %%
df = pd.read_table('xie_zheng.txt',sep=' ',delimiter="\n",encoding='utf-8')
df
# Out:
#                    2018-07-27,qDE653522676,重庆,2.5,廖凡还是可以
# 0      2018-07-27,东北爷们儿988,郑州,2.5,可看，但谈不上经典，远比《让子弹飞》差...
# 1      2018-07-27,iDo934735279,合肥,3.5,挺好看的！和姜文以前拍戏的风格...
# 2          2018-07-27,TXx147175217,东营,4,姜文电影，快节奏快剪辑。侠骨柔情
# 3                      2018-07-27,夏天的微笑322,宜昌,4,还行吧，电影一般
# 4               2018-07-27,大杏杏杏,郑州,4,经典的姜文黑色幽默，把男神演成了傻子。
# 5                                             周韵真美，彭于晏真帅
# 6                     这种片不去解析一次很难看懂，提前看了部分梗做了功课才敢去看，值得一票
# 7      2018-07-27,GvW517174950,澧县,3,动作部分蛮好笑的，其他的呃。。。个...
# 8                 2018-07-27,Fll8850,齐齐哈尔,5,好看！姜文的电影就是牛！
# 9                    2018-07-27,jlf830689082,北京,5,剧情挺不错的
# 10                           2018-07-27,浅水深白,宜昌,4,简直是浮夸…
# 11                          2018-07-27,明儿见.,孝感,4,画面拍得非常美
# 12                 2018-07-27,chenyabingai,南通,2.5,没有逻辑！！
# 13                    2018-07-27,郑媛郡,花都,1.5,不知所云！姜文在想啥呢？
# 14                   2018-07-27,Dnw153795421,珠海,5,还可以，，，
# ...

# %%
df
# Out:
#                    2018-07-27,qDE653522676,重庆,2.5,廖凡还是可以
# 0      2018-07-27,东北爷们儿988,郑州,2.5,可看，但谈不上经典，远比《让子弹飞》差...
# 1      2018-07-27,iDo934735279,合肥,3.5,挺好看的！和姜文以前拍戏的风格...
# 2          2018-07-27,TXx147175217,东营,4,姜文电影，快节奏快剪辑。侠骨柔情
# 3                      2018-07-27,夏天的微笑322,宜昌,4,还行吧，电影一般
# 4               2018-07-27,大杏杏杏,郑州,4,经典的姜文黑色幽默，把男神演成了傻子。
# 5                                             周韵真美，彭于晏真帅
# 6                     这种片不去解析一次很难看懂，提前看了部分梗做了功课才敢去看，值得一票
# 7      2018-07-27,GvW517174950,澧县,3,动作部分蛮好笑的，其他的呃。。。个...
# 8                 2018-07-27,Fll8850,齐齐哈尔,5,好看！姜文的电影就是牛！
# 9                    2018-07-27,jlf830689082,北京,5,剧情挺不错的
# 10                           2018-07-27,浅水深白,宜昌,4,简直是浮夸…
# 11                          2018-07-27,明儿见.,孝感,4,画面拍得非常美
# 12                 2018-07-27,chenyabingai,南通,2.5,没有逻辑！！
# 13                    2018-07-27,郑媛郡,花都,1.5,不知所云！姜文在想啥呢？
# 14                   2018-07-27,Dnw153795421,珠海,5,还可以，，，
# ...

# %%
df.drop_duplicates()  ##删除重复行，如果需要按照列过滤，参数选填['col1', 'col2',...]
# Out:
#                    2018-07-27,qDE653522676,重庆,2.5,廖凡还是可以
# 0      2018-07-27,东北爷们儿988,郑州,2.5,可看，但谈不上经典，远比《让子弹飞》差...
# 1      2018-07-27,iDo934735279,合肥,3.5,挺好看的！和姜文以前拍戏的风格...
# 2          2018-07-27,TXx147175217,东营,4,姜文电影，快节奏快剪辑。侠骨柔情
# 3                      2018-07-27,夏天的微笑322,宜昌,4,还行吧，电影一般
# 4               2018-07-27,大杏杏杏,郑州,4,经典的姜文黑色幽默，把男神演成了傻子。
# 5                                             周韵真美，彭于晏真帅
# 6                     这种片不去解析一次很难看懂，提前看了部分梗做了功课才敢去看，值得一票
# 7      2018-07-27,GvW517174950,澧县,3,动作部分蛮好笑的，其他的呃。。。个...
# 8                 2018-07-27,Fll8850,齐齐哈尔,5,好看！姜文的电影就是牛！
# 9                    2018-07-27,jlf830689082,北京,5,剧情挺不错的
# 10                           2018-07-27,浅水深白,宜昌,4,简直是浮夸…
# 11                          2018-07-27,明儿见.,孝感,4,画面拍得非常美
# 12                 2018-07-27,chenyabingai,南通,2.5,没有逻辑！！
# 13                    2018-07-27,郑媛郡,花都,1.5,不知所云！姜文在想啥呢？
# 14                   2018-07-27,Dnw153795421,珠海,5,还可以，，，
# ...

# %%
df.fillna(0) ## 用实数0填充na
# Out:
#                    2018-07-27,qDE653522676,重庆,2.5,廖凡还是可以
# 0      2018-07-27,东北爷们儿988,郑州,2.5,可看，但谈不上经典，远比《让子弹飞》差...
# 1      2018-07-27,iDo934735279,合肥,3.5,挺好看的！和姜文以前拍戏的风格...
# 2          2018-07-27,TXx147175217,东营,4,姜文电影，快节奏快剪辑。侠骨柔情
# 3                      2018-07-27,夏天的微笑322,宜昌,4,还行吧，电影一般
# 4               2018-07-27,大杏杏杏,郑州,4,经典的姜文黑色幽默，把男神演成了傻子。
# 5                                             周韵真美，彭于晏真帅
# 6                     这种片不去解析一次很难看懂，提前看了部分梗做了功课才敢去看，值得一票
# 7      2018-07-27,GvW517174950,澧县,3,动作部分蛮好笑的，其他的呃。。。个...
# 8                 2018-07-27,Fll8850,齐齐哈尔,5,好看！姜文的电影就是牛！
# 9                    2018-07-27,jlf830689082,北京,5,剧情挺不错的
# 10                           2018-07-27,浅水深白,宜昌,4,简直是浮夸…
# 11                          2018-07-27,明儿见.,孝感,4,画面拍得非常美
# 12                 2018-07-27,chenyabingai,南通,2.5,没有逻辑！！
# 13                    2018-07-27,郑媛郡,花都,1.5,不知所云！姜文在想啥呢？
# 14                   2018-07-27,Dnw153795421,珠海,5,还可以，，，
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=15481, step=1)

# %%
df.head(n=150)
# Out:
#                  2018-07-27,qDE653522676,重庆,2.5,廖凡还是可以
# 0    2018-07-27,东北爷们儿988,郑州,2.5,可看，但谈不上经典，远比《让子弹飞》差...
# 1    2018-07-27,iDo934735279,合肥,3.5,挺好看的！和姜文以前拍戏的风格...
# 2        2018-07-27,TXx147175217,东营,4,姜文电影，快节奏快剪辑。侠骨柔情
# 3                    2018-07-27,夏天的微笑322,宜昌,4,还行吧，电影一般
# 4             2018-07-27,大杏杏杏,郑州,4,经典的姜文黑色幽默，把男神演成了傻子。
# 5                                           周韵真美，彭于晏真帅
# 6                   这种片不去解析一次很难看懂，提前看了部分梗做了功课才敢去看，值得一票
# 7    2018-07-27,GvW517174950,澧县,3,动作部分蛮好笑的，其他的呃。。。个...
# 8               2018-07-27,Fll8850,齐齐哈尔,5,好看！姜文的电影就是牛！
# 9                  2018-07-27,jlf830689082,北京,5,剧情挺不错的
# 10                         2018-07-27,浅水深白,宜昌,4,简直是浮夸…
# 11                        2018-07-27,明儿见.,孝感,4,画面拍得非常美
# 12               2018-07-27,chenyabingai,南通,2.5,没有逻辑！！
# 13                  2018-07-27,郑媛郡,花都,1.5,不知所云！姜文在想啥呢？
# 14                 2018-07-27,Dnw153795421,珠海,5,还可以，，，
# 15             2018-07-27,gdH668466681,江门,3.5,这电影迷的我一匹
# ...

# %%
df.T
# Out:
#                                                                                    0      \
# 2018-07-27,qDE653522676,重庆,2.5,廖凡还是可以  2018-07-27,东北爷们儿988,郑州,2.5,可看，但谈不上经典，远比《让子弹飞》差...
#
#                                                                                    1      \
# 2018-07-27,qDE653522676,重庆,2.5,廖凡还是可以  2018-07-27,iDo934735279,合肥,3.5,挺好看的！和姜文以前拍戏的风格...
#
#                                                                                2      \
# 2018-07-27,qDE653522676,重庆,2.5,廖凡还是可以  2018-07-27,TXx147175217,东营,4,姜文电影，快节奏快剪辑。侠骨柔情
#
#                                                                    3      \
# 2018-07-27,qDE653522676,重庆,2.5,廖凡还是可以  2018-07-27,夏天的微笑322,宜昌,4,还行吧，电影一般
#
#                                                                           4      \
# 2018-07-27,qDE653522676,重庆,2.5,廖凡还是可以  2018-07-27,大杏杏杏,郑州,4,经典的姜文黑色幽默，把男神演成了傻子。
#
#                                             5      \
# 2018-07-27,qDE653522676,重庆,2.5,廖凡还是可以  周韵真美，彭于晏真帅
#
# ...

# %%
df2 = df.head(100)

# %%
df2.T
# Out:
#                                                                                       0   \
# 2018-07-27,qDE653522676,重庆,2.5,廖凡还是可以  2018-07-27,东北爷们儿988,郑州,2.5,可看，但谈不上经典，远比《让子弹飞》差...
#
#                                                                                       1   \
# 2018-07-27,qDE653522676,重庆,2.5,廖凡还是可以  2018-07-27,iDo934735279,合肥,3.5,挺好看的！和姜文以前拍戏的风格...
#
#                                                                                   2   \
# 2018-07-27,qDE653522676,重庆,2.5,廖凡还是可以  2018-07-27,TXx147175217,东营,4,姜文电影，快节奏快剪辑。侠骨柔情
#
#                                                                       3   \
# 2018-07-27,qDE653522676,重庆,2.5,廖凡还是可以  2018-07-27,夏天的微笑322,宜昌,4,还行吧，电影一般
#
#                                                                              4   \
# 2018-07-27,qDE653522676,重庆,2.5,廖凡还是可以  2018-07-27,大杏杏杏,郑州,4,经典的姜文黑色幽默，把男神演成了傻子。
#
#                                                5   \
# 2018-07-27,qDE653522676,重庆,2.5,廖凡还是可以  周韵真美，彭于晏真帅
#
# ...

# %%
df2.shape
# Out:
# (100, 1)

# %%
df2.columns
df2
# Out:
#                 2018-07-27,qDE653522676,重庆,2.5,廖凡还是可以
# 0   2018-07-27,东北爷们儿988,郑州,2.5,可看，但谈不上经典，远比《让子弹飞》差...
# 1   2018-07-27,iDo934735279,合肥,3.5,挺好看的！和姜文以前拍戏的风格...
# 2       2018-07-27,TXx147175217,东营,4,姜文电影，快节奏快剪辑。侠骨柔情
# 3                   2018-07-27,夏天的微笑322,宜昌,4,还行吧，电影一般
# 4            2018-07-27,大杏杏杏,郑州,4,经典的姜文黑色幽默，把男神演成了傻子。
# 5                                          周韵真美，彭于晏真帅
# 6                  这种片不去解析一次很难看懂，提前看了部分梗做了功课才敢去看，值得一票
# 7   2018-07-27,GvW517174950,澧县,3,动作部分蛮好笑的，其他的呃。。。个...
# 8              2018-07-27,Fll8850,齐齐哈尔,5,好看！姜文的电影就是牛！
# 9                 2018-07-27,jlf830689082,北京,5,剧情挺不错的
# 10                        2018-07-27,浅水深白,宜昌,4,简直是浮夸…
# 11                       2018-07-27,明儿见.,孝感,4,画面拍得非常美
# 12              2018-07-27,chenyabingai,南通,2.5,没有逻辑！！
# 13                 2018-07-27,郑媛郡,花都,1.5,不知所云！姜文在想啥呢？
# 14                2018-07-27,Dnw153795421,珠海,5,还可以，，，
# 15            2018-07-27,gdH668466681,江门,3.5,这电影迷的我一匹
# ...

# %%
df2.columns = ["null"]
df2.duplicated
df2
# Out:
#                                                  null
# 0   2018-07-27,东北爷们儿988,郑州,2.5,可看，但谈不上经典，远比《让子弹飞》差...
# 1   2018-07-27,iDo934735279,合肥,3.5,挺好看的！和姜文以前拍戏的风格...
# 2       2018-07-27,TXx147175217,东营,4,姜文电影，快节奏快剪辑。侠骨柔情
# 3                   2018-07-27,夏天的微笑322,宜昌,4,还行吧，电影一般
# 4            2018-07-27,大杏杏杏,郑州,4,经典的姜文黑色幽默，把男神演成了傻子。
# 5                                          周韵真美，彭于晏真帅
# 6                  这种片不去解析一次很难看懂，提前看了部分梗做了功课才敢去看，值得一票
# 7   2018-07-27,GvW517174950,澧县,3,动作部分蛮好笑的，其他的呃。。。个...
# 8              2018-07-27,Fll8850,齐齐哈尔,5,好看！姜文的电影就是牛！
# 9                 2018-07-27,jlf830689082,北京,5,剧情挺不错的
# 10                        2018-07-27,浅水深白,宜昌,4,简直是浮夸…
# 11                       2018-07-27,明儿见.,孝感,4,画面拍得非常美
# 12              2018-07-27,chenyabingai,南通,2.5,没有逻辑！！
# 13                 2018-07-27,郑媛郡,花都,1.5,不知所云！姜文在想啥呢？
# 14                2018-07-27,Dnw153795421,珠海,5,还可以，，，
# 15            2018-07-27,gdH668466681,江门,3.5,这电影迷的我一匹
# ...

# %%
df2
# Out:
#                                                  null
# 0   2018-07-27,东北爷们儿988,郑州,2.5,可看，但谈不上经典，远比《让子弹飞》差...
# 1   2018-07-27,iDo934735279,合肥,3.5,挺好看的！和姜文以前拍戏的风格...
# 2       2018-07-27,TXx147175217,东营,4,姜文电影，快节奏快剪辑。侠骨柔情
# 3                   2018-07-27,夏天的微笑322,宜昌,4,还行吧，电影一般
# 4            2018-07-27,大杏杏杏,郑州,4,经典的姜文黑色幽默，把男神演成了傻子。
# 5                                          周韵真美，彭于晏真帅
# 6                  这种片不去解析一次很难看懂，提前看了部分梗做了功课才敢去看，值得一票
# 7   2018-07-27,GvW517174950,澧县,3,动作部分蛮好笑的，其他的呃。。。个...
# 8              2018-07-27,Fll8850,齐齐哈尔,5,好看！姜文的电影就是牛！
# 9                 2018-07-27,jlf830689082,北京,5,剧情挺不错的
# 10                        2018-07-27,浅水深白,宜昌,4,简直是浮夸…
# 11                       2018-07-27,明儿见.,孝感,4,画面拍得非常美
# 12              2018-07-27,chenyabingai,南通,2.5,没有逻辑！！
# 13                 2018-07-27,郑媛郡,花都,1.5,不知所云！姜文在想啥呢？
# 14                2018-07-27,Dnw153795421,珠海,5,还可以，，，
# 15            2018-07-27,gdH668466681,江门,3.5,这电影迷的我一匹
# ...

# %%
df = pd.save_txt('xie_zheng.txt',sep=' ',delimiter="\n",encoding='utf-8')

# %%
df
# Out:
#                    2018-07-27,qDE653522676,重庆,2.5,廖凡还是可以
# 0      2018-07-27,东北爷们儿988,郑州,2.5,可看，但谈不上经典，远比《让子弹飞》差...
# 1      2018-07-27,iDo934735279,合肥,3.5,挺好看的！和姜文以前拍戏的风格...
# 2          2018-07-27,TXx147175217,东营,4,姜文电影，快节奏快剪辑。侠骨柔情
# 3                      2018-07-27,夏天的微笑322,宜昌,4,还行吧，电影一般
# 4               2018-07-27,大杏杏杏,郑州,4,经典的姜文黑色幽默，把男神演成了傻子。
# 5                                             周韵真美，彭于晏真帅
# 6                     这种片不去解析一次很难看懂，提前看了部分梗做了功课才敢去看，值得一票
# 7      2018-07-27,GvW517174950,澧县,3,动作部分蛮好笑的，其他的呃。。。个...
# 8                 2018-07-27,Fll8850,齐齐哈尔,5,好看！姜文的电影就是牛！
# 9                    2018-07-27,jlf830689082,北京,5,剧情挺不错的
# 10                           2018-07-27,浅水深白,宜昌,4,简直是浮夸…
# 11                          2018-07-27,明儿见.,孝感,4,画面拍得非常美
# 12                 2018-07-27,chenyabingai,南通,2.5,没有逻辑！！
# 13                    2018-07-27,郑媛郡,花都,1.5,不知所云！姜文在想啥呢？
# 14                   2018-07-27,Dnw153795421,珠海,5,还可以，，，
# ...
